# %% [markdown]
# <a href="https://colab.research.google.com/github/ricardomza04-debug/Notebooks_Agro/blob/main/Notebook_semana_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ENTRADA: entra ancho y alto de la madera en metros
ancho = input('ingresa el ancho de la ventana en metros')
ancho = float(ancho)
alto = input('ingresa el alto de la ventana en metros')
alto = float(alto)

# PROCESOS: calcula longuitud de la madera (lm) en pies
#y el area del vidrio en metros cuadrados
lm = 2 * (ancho + alto) * 3.25
av = 2 * (ancho * alto)

#SALIDA: sale la longuitud de la madera en pies
# el area del vidrio en metros cuadrados
print('longuitud de la madera es ', lm, 'pies de longuitud')
print(' el area del vidrio es', av, 'metros cuadrados')
# Out:
# ingresa el ancho de la ventana en metros1
# ingresa el alto de la ventana en metros2
# longuitud de la madera es  19.5 pies de longuitud
#  el area del vidrio es 4.0 metros cuadrados
